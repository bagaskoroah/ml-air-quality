# %%
# Import the required libraries.
import copy
import hashlib
import json

# Need to be installed.
import joblib
import time
import yaml
import pandas as pd
import numpy as np

from sklearn.dummy import DummyClassifier
from sklearn.neighbors import KNeighborsClassifier as KNN
from sklearn.tree import DecisionTreeClassifier as DTC
from sklearn.linear_model import LogisticRegression as LGR
from sklearn.ensemble import BaggingClassifier as BGC, RandomForestClassifier as RFC, AdaBoostClassifier as ABC, GradientBoostingClassifier as GBC

from sklearn.metrics import classification_report
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV

from datetime import datetime
from tqdm import tqdm

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # **0. Configuration File**

# %%
def load_config(path_config):
    """
    Load the configuration file (config.yaml).

    Parameters:
    ----------
    path_config : str
        Configuration file location.

    Returns:
    -------
    params : dict
        The configuration parameters.
    """

    # try to load config.yaml file
    try:
        with open(path_config, 'r') as file:
            config = yaml.safe_load(file)
    except FileNotFoundError:
        raise FileNotFoundError(f'Configuration file is not found in {path_config}.')
    except yaml.YAMLError as e:
        raise ValueError('Invalid yaml format') from e
    
    return config

# %%
# Function to update configuration parameter.
def update_config(key, value, config, path_config):
    """
    Update the configuration parameter values.

    Parameters:
    ----------
    key : str
        The key to be updated.

    value : any type supported in Python
        The updated value.

    config : dict
        Loaded configuration parameters.

    path_config : str
        Configuration file location.

    Returns:
    -------
    config : dict
        Updated configuration parameters.
    """

    # To maintain the raw config immutable.
    config = config.copy()

    # Update the configuration parameters.
    config[key] = value

    with open(path_config, 'w') as file:
        yaml.dump(config, file)

    print(f"Config Updated! \nKey: {key} \nValue: {value}\n")

    # Reload the updated configuration parameters.
    config = load_config(path_config)

    return config

# %%
# load config
config_path = '../config/config.yaml'
config = load_config(path_config=config_path)
config
# Out:
# {'co_range': [-1, 47],
#  'datetime_columns': ['tanggal'],
#  'features': ['stasiun', 'pm10', 'pm25', 'so2', 'co', 'o3', 'no2'],
#  'impute_co': 11.0,
#  'impute_no2': 18.0,
#  'impute_o3': 29.0,
#  'impute_pm10': {'BAIK': 28.683098591549296, 'TIDAK BAIK': 55.53523357086303},
#  'impute_pm25': {'BAIK': 39.472727272727276, 'TIDAK BAIK': 82.82560879811469},
#  'impute_so2': 35.01016702977487,
#  'int32_columns': ['pm10', 'pm25', 'so2', 'co', 'o3', 'no2', 'max'],
#  'label': 'category',
#  'label_categories': ['BAIK', 'SEDANG', 'TIDAK SEHAT'],
#  'label_categories_new': ['BAIK', 'TIDAK BAIK'],
#  'no2_range': [-1, 65],
#  'o3_range': [-1, 151],
#  'object_columns': ['stasiun', 'critical', 'category'],
#  'path_joined_data': '../data/interim/joined_dataset.pkl',
#  'path_ohe_stasiun': '../models/ohe_stasiun.pkl',
#  'path_test_set': ['../data/interim/X_test.pkl', '../data/interim/y_test.pkl'],
#  'path_train_set': ['../data/interim/X_train.pkl',
#   '../data/interim/y_train.pkl'],
#  'path_valid_set': ['../data/interim/X_valid.pkl',
#   '../data/interim/y_valid.pkl'],
#  'pm10_range': [-1, 179],
#  'pm25_range': [-1, 174],
#  'range_stasiun': ['DKI1 (Bunderan HI)',
#   'DKI2 (Kelapa Gading)',
#   'DKI3 (Jagakarsa)',
#   'DKI4 (Lubang Buaya)',
#   'DKI5 (Kebon Jeruk) Jakarta Barat'],
#  'raw_data_path': '../data/raw/',
#  'so2_range': [-1, 82]}

# %% [markdown]
# # **1. Load Dataset**

# %%
# undersampling
X_rus = joblib.load("../data/processed/X_rus.pkl")
y_rus = joblib.load("../data/processed/y_rus.pkl")

# oversampling
X_ros = joblib.load("../data/processed/X_ros.pkl")
y_ros = joblib.load("../data/processed/y_ros.pkl")

# smote
X_sm = joblib.load("../data/processed/X_sm.pkl")
y_sm = joblib.load("../data/processed/y_sm.pkl")

# valid
X_valid = joblib.load("../data/processed/X_valid_feng.pkl")
y_valid = joblib.load("../data/processed/y_valid_feng.pkl")

# test
X_test = joblib.load("../data/processed/X_test_feng.pkl")
y_test = joblib.load("../data/processed/y_test_feng.pkl")

# %% [markdown]
# # **2. Create Log Template**

# %%
# function to support training log
def time_stamp():
    return datetime.now()

def create_log_template():
    logger = {
        'model_name': [],
        'model_id': [],
        'training_time': [],
        'training_date': [],
        'performance': [],
        'f1_score_avg': [],
        'data_configuration': []
    }

    return logger

# %%
def update_training_log(current_log, log_path):

    """
    Update the training log.

    Parameters:
    ----------
    current_log : dict
        The training log current state.

    log_path : str
        The directory of training log.

    Returns:
    -------
    last_log : dict
        The updated training log.
    """

    # make a copy log so it wont affect the real one
    current_log = current_log.copy()

    # open log training file
    try:
        with open(log_path, 'r') as file:
            last_log = json.load(file)
    
    # if there is no training file in path
    except FileNotFoundError:
        # make a new training log file
        with open(log_path, 'w') as file:
            file.write('[]')
        
        # then re-load the file after making new one
        with open(log_path, 'r') as file:
            last_log = json.load(file)
    
    # add a new log to current log
    last_log.append(current_log)

    # rewrite and save the updated log
    with open(log_path, 'w') as file:
        json.dump(last_log, file)

    # return updated log
    return last_log

# %% [markdown]
# # **3. Model Training**

# %%
# create model object
baseline = DummyClassifier()
knn = KNN()
dtc = DTC()
lgr = LGR()
bgc = BGC()
rfc = RFC()
abc = ABC()
gbc = GBC()

# %%
list_of_model = {
    'undersampling': [
        {'model_name': baseline.__class__.__name__, 'model_object': baseline, 'model_id': ''},
        {'model_name': knn.__class__.__name__, 'model_object': knn, 'model_id': ''},
        {'model_name': dtc.__class__.__name__, 'model_object': dtc, 'model_id': ''},
        {'model_name': lgr.__class__.__name__, 'model_object': lgr, 'model_id': ''},
        {'model_name': bgc.__class__.__name__, 'model_object': bgc, 'model_id': ''},
        {'model_name': rfc.__class__.__name__, 'model_object': rfc, 'model_id': ''},
        {'model_name': abc.__class__.__name__, 'model_object': abc, 'model_id': ''},
        {'model_name': gbc.__class__.__name__, 'model_object': gbc, 'model_id': ''}
    ],
    'oversampling': [
        {'model_name': baseline.__class__.__name__, 'model_object': baseline, 'model_id': ''},
        {'model_name': knn.__class__.__name__, 'model_object': knn, 'model_id': ''},
        {'model_name': dtc.__class__.__name__, 'model_object': dtc, 'model_id': ''},
        {'model_name': lgr.__class__.__name__, 'model_object': lgr, 'model_id': ''},
        {'model_name': bgc.__class__.__name__, 'model_object': bgc, 'model_id': ''},
        {'model_name': rfc.__class__.__name__, 'model_object': rfc, 'model_id': ''},
        {'model_name': abc.__class__.__name__, 'model_object': abc, 'model_id': ''},
        {'model_name': gbc.__class__.__name__, 'model_object': gbc, 'model_id': ''}
    ],
    'smote': [
        {'model_name': baseline.__class__.__name__, 'model_object': baseline, 'model_id': ''},
        {'model_name': knn.__class__.__name__, 'model_object': knn, 'model_id': ''},
        {'model_name': dtc.__class__.__name__, 'model_object': dtc, 'model_id': ''},
        {'model_name': lgr.__class__.__name__, 'model_object': lgr, 'model_id': ''},
        {'model_name': bgc.__class__.__name__, 'model_object': bgc, 'model_id': ''},
        {'model_name': rfc.__class__.__name__, 'model_object': rfc, 'model_id': ''},
        {'model_name': abc.__class__.__name__, 'model_object': abc, 'model_id': ''},
        {'model_name': gbc.__class__.__name__, 'model_object': gbc, 'model_id': ''}
    ],
}

# %%
def train_eval_model(list_of_model, prefix_model_name, X_train, y_train, data_configuration, X_valid, y_valid, log_path):
    list_of_model = copy.deepcopy(list_of_model)

    logger = create_log_template()

    for model in tqdm(list_of_model):
        model_name = f'{prefix_model_name} - {model['model_name']}'

        start_time = time_stamp()
        model['model_object'].fit(X_train, y_train)
        finished_time = time_stamp()

        elapsed_time = finished_time - start_time
        elapsed_time = elapsed_time.total_seconds()

        y_pred = model['model_object'].predict(X_valid)
        performance = classification_report(y_valid, y_pred, output_dict=True)

        plain_id = str(start_time) + str(finished_time)
        cipher_id = hashlib.md5(plain_id.encode()).hexdigest()

        model['model_id'] = cipher_id

        logger['model_name'].append(model_name)
        logger['model_id'].append(cipher_id)
        logger['training_time'].append(elapsed_time)
        logger['training_date'].append(str(start_time))
        logger['performance'].append(performance)
        logger['f1_score_avg'].append(performance['macro avg']['f1-score'])
        logger['data_configuration'].append(data_configuration)

    training_log = update_training_log(logger, log_path)

    return training_log, list_of_model

# %%
path_log = '../logs/training_log.json'

# %%
# training using random undersampler object

training_log, list_of_model_rus = train_eval_model(
    list_of_model = list_of_model['undersampling'],
    prefix_model_name = 'first',
    X_train = X_rus,
    y_train = y_rus,
    data_configuration='undersampling',
    X_valid = X_valid,
    y_valid = y_valid,
    log_path = path_log
)
# Out:
# 100%|██████████| 8/8 [00:00<00:00, 12.93it/s]

# %%
list_of_model['undersampling'] = copy.deepcopy(list_of_model_rus)

# %%
training_log, list_of_model_ros = train_eval_model(
    list_of_model['oversampling'],
    "first",
    X_ros,
    y_ros,
    "oversampling",
    X_valid,
    y_valid,
    path_log
)
# Out:
# 100%|██████████| 8/8 [00:00<00:00, 10.24it/s]

# %%
list_of_model['oversampling'] = copy.deepcopy(list_of_model_ros)

# %%
training_log, list_of_model_sm = train_eval_model(
    list_of_model['smote'],
    "first",
    X_sm,
    y_sm,
    "smote",
    X_valid,
    y_valid,
    path_log
)
# Out:
# 100%|██████████| 8/8 [00:01<00:00,  7.36it/s]

# %%
list_of_model['smote'] = copy.deepcopy(list_of_model_sm)

# %%
def training_log_to_df(training_log):
    training_res = pd.DataFrame()

    for log in tqdm(training_log):
        training_res = pd.concat([training_res, pd.DataFrame(log)])

    training_res.sort_values(['f1_score_avg', 'training_time'], ascending=[False, True], inplace=True)
    training_res.reset_index(inplace=True, drop=True)
    return training_res

# %%
training_res = training_log_to_df(training_log=training_log)
# Out:
# 100%|██████████| 3/3 [00:00<00:00, 447.95it/s]

# %%
training_res
# Out:
#                             model_name                          model_id  \
# 0       first - DecisionTreeClassifier  7f911e71ecd720a60fa78c31dc5e491a
# 1       first - DecisionTreeClassifier  66eb2ac5cfc70e5f67f962dc4ecdcb88
# 2            first - BaggingClassifier  1db6b67e3c93ea5ef7848f984f100c90
# 3            first - BaggingClassifier  3a3517753107b2b3dd2ae0980589b34a
# 4           first - AdaBoostClassifier  314a7a12af55575cdc94930eefdd589f
# 5           first - AdaBoostClassifier  7ea602746cfdc485751408984996e588
# 6   first - GradientBoostingClassifier  296fc099ae8b40695e5ae8dca80a6239
# 7   first - GradientBoostingClassifier  a7597104cd843f5fe5d184567baa75ba
# 8       first - DecisionTreeClassifier  235eafbed0c19e54dd75ee997da70f55
# 9            first - BaggingClassifier  c84273137df48ef92b203aa9138ac1e4
# 10  first - GradientBoostingClassifier  76f3c057c4370bad0b0913016f55f2c5
# 11          first - AdaBoostClassifier  5776037222dde3f32f76d1bac8b1f9a9
# 12      first - RandomForestClassifier  8f0d46c90c740ed2700ca80ab72d880c
# 13      first - RandomForestClassifier  ce42a2ce15f766e51dfb51facb6bc83b
# 14      first - RandomForestClassifier  dd435f3e83aa6274f5959900a7adfbc1
# 15          first - LogisticRegression  5b4118d57e8f9f186bbf72f82364b398
# 16          first - LogisticRegression  9ced9e6fb110ab4113c59cb91f862449
# 17        first - KNeighborsClassifier  c8dc9143e53f427bdf730a2dabeb9952
# 18        first - KNeighborsClassifier  8699256cceee82438fec93876eaa1677
# 19          first - LogisticRegression  25b9c96ac84e599a59dba3f26dce3d98
# 20        first - KNeighborsClassifier  d4d6381a09a9bdab82bddc9c146fa94a
# 21             first - DummyClassifier  9e34718f638e9d01b96cc4dbbe3594ee
# 22             first - DummyClassifier  f598e25e08e7c60347061ab19cb44572
# 23             first - DummyClassifier  9aa30bae9b46920d75ed5fe30b2703c1
#
#     training_time               training_date  \
# 0        0.004520  2026-02-12 08:21:56.104462
# 1        0.007039  2026-02-12 08:21:56.944440
# 2        0.046920  2026-02-12 08:21:56.141280
# 3        0.066725  2026-02-12 08:21:57.009021
# 4        0.132184  2026-02-12 08:21:56.433469
# 5        0.153990  2026-02-12 08:21:57.412401
# 6        0.264734  2026-02-12 08:21:56.579428
# 7        0.402596  2026-02-12 08:21:57.581089
# 8        0.005834  2026-02-12 08:21:55.454301
# 9        0.043819  2026-02-12 08:21:55.582270
# 10       0.088914  2026-02-12 08:21:55.919529
# 11       0.104261  2026-02-12 08:21:55.798680
# 12       0.143918  2026-02-12 08:21:55.637027
# 13       0.212702  2026-02-12 08:21:56.202943
# 14       0.310994  2026-02-12 08:21:57.084876
# 15       0.037044  2026-02-12 08:21:56.960406
# 16       0.008138  2026-02-12 08:21:56.119196
# 17       0.004585  2026-02-12 08:21:56.086925
# 18       0.006009  2026-02-12 08:21:56.922338
# 19       0.065248  2026-02-12 08:21:55.482807
# 20       0.007223  2026-02-12 08:21:55.422929
# 21       0.001102  2026-02-12 08:21:56.070890
# 22       0.001210  2026-02-12 08:21:56.905544
# 23       0.005324  2026-02-12 08:21:55.398035
#
#                                           performance  f1_score_avg  \
# 0   {'0': {'precision': 1.0, 'recall': 1.0, 'f1-sc...      1.000000
# 1   {'0': {'precision': 1.0, 'recall': 1.0, 'f1-sc...      1.000000
# 2   {'0': {'precision': 1.0, 'recall': 1.0, 'f1-sc...      1.000000
# 3   {'0': {'precision': 1.0, 'recall': 1.0, 'f1-sc...      1.000000
# 4   {'0': {'precision': 1.0, 'recall': 1.0, 'f1-sc...      1.000000
# 5   {'0': {'precision': 1.0, 'recall': 1.0, 'f1-sc...      1.000000
# 6   {'0': {'precision': 1.0, 'recall': 1.0, 'f1-sc...      1.000000
# 7   {'0': {'precision': 1.0, 'recall': 1.0, 'f1-sc...      1.000000
# 8   {'0': {'precision': 0.95, 'recall': 1.0, 'f1-s...      0.985631
# 9   {'0': {'precision': 0.95, 'recall': 1.0, 'f1-s...      0.985631
# 10  {'0': {'precision': 0.95, 'recall': 1.0, 'f1-s...      0.985631
# 11  {'0': {'precision': 0.95, 'recall': 1.0, 'f1-s...      0.985631
# 12  {'0': {'precision': 0.95, 'recall': 1.0, 'f1-s...      0.985631
# 13  {'0': {'precision': 1.0, 'recall': 0.947368421...      0.984948
# 14  {'0': {'precision': 1.0, 'recall': 0.947368421...      0.984948
# 15  {'0': {'precision': 0.7307692307692307, 'recal...      0.911181
# 16  {'0': {'precision': 0.7037037037037037, 'recal...      0.900385
# 17  {'0': {'precision': 0.6071428571428571, 'recal...      0.841067
# 18  {'0': {'precision': 0.6071428571428571, 'recal...      0.841067
# 19  {'0': {'precision': 0.5806451612903226, 'recal...      0.837564
# 20  {'0': {'precision': 0.4864864864864865, 'recal...      0.788749
# 21  {'0': {'precision': 0.10497237569060773, 'reca...      0.095000
# 22  {'0': {'precision': 0.10497237569060773, 'reca...      0.095000
# 23  {'0': {'precision': 0.10497237569060773, 'reca...      0.095000
#
#    data_configuration
# 0        oversampling
# 1               smote
# 2        oversampling
# 3               smote
# 4        oversampling
# 5               smote
# 6        oversampling
# 7               smote
# 8       undersampling
# 9       undersampling
# 10      undersampling
# 11      undersampling
# 12      undersampling
# 13       oversampling
# 14              smote
# 15              smote
# 16       oversampling
# 17       oversampling
# 18              smote
# 19      undersampling
# 20      undersampling
# 21       oversampling
# 22              smote
# 23      undersampling

# %% [markdown]
# # **4. Model Tuning**

# %%
# function to evaluate model
def evaluate_model(estimator, param_space, X_train, y_train):
    '''
    Do hyperparameter tuning and cross validation
    '''

    # create tuner object
    tuner = RandomizedSearchCV(
        estimator=estimator,
        param_distributions=param_space,
        n_iter=100,
        scoring='f1',
        cv=5,
        return_train_score=True,
        n_jobs=-1,
        verbose=1
    )

    # fit the tuner -> CV + HT
    tuner.fit(X_train, y_train)

    # get the best model
    best_model = tuner.best_estimator_

    # predict the data using best_model
    y_train_pred = best_model.predict(X_train)

    # get the scores from the best model
    best_index = tuner.best_index_
    train_f1 = tuner.cv_results_['mean_train_score'][best_index]
    cv_f1 = tuner.cv_results_['mean_test_score'][best_index]

    print(f'Train F1: {train_f1}')
    print(f'CV F1: {cv_f1}')

    return best_model, train_f1, cv_f1

# %% [markdown]
# Assume that we tune our model on smote data.

# %% [markdown]
# ## **K-Nearest Neighbors**

# %%
# Record the start time.
start_time = time.time()

# hyperparameter for KNN
knn_params = {
    'n_neighbors': np.arange(1,13),
    'weights': ['uniform', 'distance'],
    'p': [1, 2]
}

# Evaluate the model.
knn_best_sm, knn_f1_sm, knn_f1_cv_sm = evaluate_model(
    estimator = knn,
    param_space = knn_params,
    X_train = X_sm,
    y_train = y_sm
)

# Record the end time.
end_time = time.time()

# Calculate the total fitting time.
fitting_time = end_time - start_time
minutes, seconds = divmod(fitting_time, 60)
print(f"Fitting Time : {int(minutes):02d} minutes {int(seconds):02d} seconds\n")

knn_best_sm
# Out:
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# Train F1: 1.0
# CV F1: 0.9851727881686656
# Fitting Time : 00 minutes 07 seconds
# KNeighborsClassifier(n_neighbors=np.int64(1))

# %% [markdown]
# ## **Logistic Regression**

# %%
# Hyperparameter for LGR.
C = [0.01, 0.1, 1.0, 10.0]

# Define hyperparameter space.
lgr_params = {
    "C": C
}

# Record the start time.
start_time = time.time()

# Evaluate the model.
lgr_best_sm, lgr_f1_sm, lgr_f1_cv_sm = evaluate_model(
    estimator = lgr,
    param_space = lgr_params,
    X_train = X_sm,
    y_train = y_sm
)

# Record the end time.
end_time = time.time()

# Calculate the total fitting time.
fitting_time = end_time - start_time
minutes, seconds = divmod(fitting_time, 60)
print(f"Fitting Time : {int(minutes):02d} minutes {int(seconds):02d} seconds\n")

lgr_best_sm
# Out:
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Train F1: 0.9781416463851411
# CV F1: 0.975366646276355
# Fitting Time : 00 minutes 00 seconds
# LogisticRegression(C=10.0)

# %% [markdown]
# ## **Decision Tree Classifier**

# %%
# Hyperparameter for DTC
DEPTH = np.arange(1, 13)

# Define hyperparameter space.
dtc_params = {
    "max_depth": DEPTH
}

# Record the start time.
start_time = time.time()

# Evaluate the model.
dtc_best_sm, dtc_f1_sm, dtc_f1_cv_sm = evaluate_model(
    estimator = dtc,
    param_space = dtc_params,
    X_train = X_sm,
    y_train = y_sm
)

# Record the end time.
end_time = time.time()

# Calculate the total fitting time.
fitting_time = end_time - start_time
minutes, seconds = divmod(fitting_time, 60)
print(f"Fitting Time : {int(minutes):02d} minutes {int(seconds):02d} seconds\n")

dtc_best_sm
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# Train F1: 0.9992294725363984
# CV F1: 0.9980702247998968
# Fitting Time : 00 minutes 00 seconds
# DecisionTreeClassifier(max_depth=np.int64(3))

# %% [markdown]
# ## **Bagging Classifier**

# %%
# Define hyperparameter space.
B = [10, 50, 100, 150, 200, 250, 300, 350, 400, 450, 500]

bgc_params = {
    "n_estimators": B
}

# Record the start time.
start_time = time.time()

# Evaluate the model.
bgc_best_sm, bgc_f1_sm, bgc_f1_cv_sm = evaluate_model(
    estimator = bgc,
    param_space = bgc_params,
    X_train = X_sm,
    y_train = y_sm
)


# Record the end time.
end_time = time.time()

# Calculate the total fitting time.
fitting_time = end_time - start_time
minutes, seconds = divmod(fitting_time, 60)
print(f"Fitting Time : {int(minutes):02d} minutes {int(seconds):02d} seconds\n")

bgc_best_sm
# Out:
# Fitting 5 folds for each of 11 candidates, totalling 55 fits
# Train F1: 1.0
# CV F1: 0.9984541019592058
# Fitting Time : 00 minutes 13 seconds
# BaggingClassifier(n_estimators=50)

# %% [markdown]
# ## **Random Forest Classifier**

# %%
# Define hyperparameter space.
B = [10, 50, 100, 150, 200, 250, 300, 350, 400, 450, 500]
DEPTH = np.arange(1, 13)

rfc_params = {
    "n_estimators": B,
    "max_depth": DEPTH
}

# Record the start time.
start_time = time.time()

# Evaluate the model.
rfc_best_sm, rfc_f1_sm, rfc_f1_cv_sm = evaluate_model(
    estimator = rfc,
    param_space = rfc_params,
    X_train = X_sm,
    y_train = y_sm
)

# Record the end time.
end_time = time.time()

# Calculate the total fitting time.
fitting_time = end_time - start_time
minutes, seconds = divmod(fitting_time, 60)
print(f"Fitting Time : {int(minutes):02d} minutes {int(seconds):02d} seconds\n")

rfc_best_sm
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# Train F1: 1.0
# CV F1: 0.9992277992277993
# Fitting Time : 01 minutes 09 seconds
# RandomForestClassifier(max_depth=np.int64(6), n_estimators=200)

# %% [markdown]
# ## **Adaboost Classifier**

# %%
# Define hyperparameter space.
B = [10, 50, 100, 150, 200, 250, 300, 350, 400, 450, 500]
LR = [0.001, 0.01, 0.05, 0.1, 1]

abc_params = {
    "n_estimators": B,
    "learning_rate": LR
}

# Record the start time.
start_time = time.time()

# Evaluate the model.
abc_best_sm, abc_f1_sm, abc_f1_cv_sm = evaluate_model(
    estimator = abc,
    param_space = abc_params,
    X_train = X_sm,
    y_train = y_sm
)

# Record the end time.
end_time = time.time()

# Calculate the total fitting time.
fitting_time = end_time - start_time
minutes, seconds = divmod(fitting_time, 60)
print(f"Fitting Time : {int(minutes):02d} minutes {int(seconds):02d} seconds\n")

abc_best_sm
# Out:
# Fitting 5 folds for each of 55 candidates, totalling 275 fits
# Train F1: 1.0
# CV F1: 0.9980805716943385
# Fitting Time : 00 minutes 45 seconds
# AdaBoostClassifier(learning_rate=1, n_estimators=100)

# %% [markdown]
# ## **Gradient Boosting Classifier**

# %%
# Define hyperparameter space.
B = [10, 50, 100, 150, 200, 250, 300, 350, 400, 450, 500]
LR = [0.001, 0.01, 0.05, 0.1, 1]
DEPTH = np.arange(1, 13)

gbc_params = {
    "n_estimators": B,
    "learning_rate": LR,
    "max_depth": DEPTH
}

# Record the start time.
start_time = time.time()

# Evaluate the model.
gbc_best_sm, gbc_f1_sm, gbc_f1_cv_sm = evaluate_model(
    estimator = gbc,
    param_space = gbc_params,
    X_train = X_sm,
    y_train = y_sm
)

# Record the end time.
end_time = time.time()

# Calculate the total fitting time.
fitting_time = end_time - start_time
minutes, seconds = divmod(fitting_time, 60)
print(f"Fitting Time : {int(minutes):02d} minutes {int(seconds):02d} seconds\n")

gbc_best_sm
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# Train F1: 1.0
# CV F1: 0.9988394584139264
# Fitting Time : 00 minutes 58 seconds
# GradientBoostingClassifier(max_depth=np.int64(2), n_estimators=200)

# %% [markdown]
# # **5. Performance Summary**

# %%
# Create a summary dataframe of train vs CV performance.
performance = {
    "Model": ["KNN", "LGR", "DTC", "BGC", "RFC", "ABC", "GBC"],
    "Train F1": [knn_f1_sm, lgr_f1_sm, dtc_f1_sm, bgc_f1_sm, rfc_f1_sm, abc_f1_sm, gbc_f1_sm],
    "CV F1": [knn_f1_cv_sm, lgr_f1_cv_sm, dtc_f1_cv_sm, bgc_f1_cv_sm, rfc_f1_cv_sm, abc_f1_cv_sm, gbc_f1_cv_sm]
}

summary_df = pd.DataFrame(performance)
summary_df
# Out:
#   Model  Train F1     CV F1
# 0   KNN  1.000000  0.985173
# 1   LGR  0.978142  0.975367
# 2   DTC  0.999229  0.998070
# 3   BGC  1.000000  0.998454
# 4   RFC  1.000000  0.999228
# 5   ABC  1.000000  0.998081
# 6   GBC  1.000000  0.998839

# %% [markdown]
# # **6. Model Serialization**

# %%
# model serialization
path_production_model = '../models/best_model.pkl'
joblib.dump(dtc_best_sm, path_production_model)
# Out:
# ['../models/best_model.pkl']

# %%
# Update the configuration parameter.
config = update_config(
    key = "path_production_model",
    value = path_production_model,
    config = config,
    path_config = config_path
)
# Out:
# Config Updated!
# Key: path_production_model
# Value: ../models/best_model.pkl
